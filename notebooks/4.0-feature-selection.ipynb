# %% [markdown]
# # Feature Selection Phase
# In this notebook I'm performing the feature selection on our train and test sets in order to produce more reliable predictions with our models.
#
# **Auhtor**: Arthur G.
# ***

# %% [markdown]
# ## Loading Dependencies
# Here I'm loading all the dependencies for this notebook.

# %%
# adding custom functions
import sys
sys.path.append('../')

# libs
import os
import joblib
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# settings
seed = np.random.seed(42)
pd.set_option('display.precision', 3)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Loading Train and Test Sets
# Here I'm loading our serialized tran and test sets.

# %%
# loading predictors
x_train = pd.read_csv(os.path.join('..', 'data', 'processed', 'x_train.csv'))
x_test = pd.read_csv(os.path.join('..', 'data', 'processed', 'x_test.csv'))

# loading targets
y_train = pd.read_csv(os.path.join('..', 'data', 'processed', 'y_train.csv'))
y_test = pd.read_csv(os.path.join('..', 'data', 'processed', 'y_test.csv'))

x_train.head()
# Out:
#    DEPARTURE_ARRIVAL_DURATION  ARRIVAL_DEPARTURE_DURATION  STOPOVERS  \
# 0                       0.387                       0.399      0.000
# 1                       0.852                       0.844      0.091
# 2                       0.852                       0.862      0.000
# 3                       0.603                       0.616      0.000
# 4                       0.812                       0.799      0.000
#
#    VESSEL_TYPE  HULL_MATERIAL  VESSEL_LENGTH  VESSEL_BEAN  VESSEL_DRAFT  \
# 0        0.833          1.000          0.691        0.643         0.440
# 1        0.667          0.667          0.494        0.498         0.325
# 2        0.667          0.667          0.441        0.643         0.325
# 3        0.667          0.667          0.505        0.445         0.456
# 4        0.667          0.667          0.303        0.217         0.259
#
#    VESSEL_DEPTH  MOTOR_POWER  SPEED  NUM_PROPELLERS  NUM_GENERATORS    DWT  \
# 0         0.364        0.088  0.383            0.25             0.4  0.113
# 1         0.364        0.045  0.124            0.25             0.4  0.102
# 2         0.186        0.028  0.792            0.25             0.4  0.102
# 3         0.382        0.106  0.548            0.25             0.4  0.022
# 4         0.213        0.045  0.225            0.00             0.2  0.102
#
#    DWT_na  LIGHT_DISPLACEMENT  LIGHT_DISPLACEMENT_na   CREW  PASS_CAPACITY  \
# 0     0.0               0.542                    0.0  0.381          0.158
# 1     1.0               0.558                    1.0  0.143          0.033
# 2     1.0               0.558                    1.0  0.095          0.025
# 3     0.0               0.251                    0.0  0.238          0.050
# 4     1.0               0.558                    1.0  0.048          0.013
#
#    LOAD_CAPACITY
# 0          0.098
# 1          0.109
# 2          0.013
# 3          0.019
# 4          0.000

# %% [markdown]
# ## Lasso for Feature Selection
# Before understanding the use of LASSO for feature selection, let's first state what regularization is.
#
# Regularization is a concept in machine learning and statistics that is used to avoid over-fitting a model with the dataset by adding penalty to achieve less variance with the test data. It reduces parameters and simplifies the model for it to have the lowest over-fitting.
#
# LASSO makes use of two types of penalties to shrink it's coefficients towards zero and then eliminate weak predictors from the equation.
#
# ### L1 Regularization
# This penalty is added to the absolute (mode) value of the magnitude of coefficients. In this process, weak coefficients will become zero, getting excluded from the analysis.
#
# ### L2 Regularization
# This penalty is added to the square of the magnitude of coefficients. In this process some coefficients also become zero and get excluded from the equation.
#
# Feature selection with LASSO is nothing more than getting to know which coefficient is greater than zero.

# %%
selector_ = SelectFromModel(Lasso(alpha=0.001, random_state=seed))
selector_.fit(x_train, y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.001))

# %% [markdown]
# Now let's see which columns do we still have.

# %%
selected_features = x_train.columns[(selector_.get_support())]
x_train[selected_features].head()
# Out:
#    DEPARTURE_ARRIVAL_DURATION  STOPOVERS  VESSEL_TYPE  HULL_MATERIAL  \
# 0                       0.387      0.000        0.833          1.000
# 1                       0.852      0.091        0.667          0.667
# 2                       0.852      0.000        0.667          0.667
# 3                       0.603      0.000        0.667          0.667
# 4                       0.812      0.000        0.667          0.667
#
#    VESSEL_LENGTH  VESSEL_BEAN  VESSEL_DRAFT  VESSEL_DEPTH  MOTOR_POWER  SPEED  \
# 0          0.691        0.643         0.440         0.364        0.088  0.383
# 1          0.494        0.498         0.325         0.364        0.045  0.124
# 2          0.441        0.643         0.325         0.186        0.028  0.792
# 3          0.505        0.445         0.456         0.382        0.106  0.548
# 4          0.303        0.217         0.259         0.213        0.045  0.225
#
#    NUM_PROPELLERS  NUM_GENERATORS    DWT  DWT_na  LIGHT_DISPLACEMENT   CREW  \
# 0            0.25             0.4  0.113     0.0               0.542  0.381
# 1            0.25             0.4  0.102     1.0               0.558  0.143
# 2            0.25             0.4  0.102     1.0               0.558  0.095
# 3            0.25             0.4  0.022     0.0               0.251  0.238
# 4            0.00             0.2  0.102     1.0               0.558  0.048
#
#    PASS_CAPACITY  LOAD_CAPACITY
# 0          0.158          0.098
# 1          0.033          0.109
# 2          0.025          0.013
# 3          0.050          0.019
# 4          0.013          0.000

# %% [markdown]
# Saving the selected features indicators.

# %%
pd.Series(selected_features).to_csv(os.path.join('..', 'data', 'interim', 'selected_features.csv'), index=False)

# %% [markdown]
# This concludes our feature selection phase.
